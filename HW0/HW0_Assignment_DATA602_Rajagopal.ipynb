# %% [markdown]
# #DATA601 : HW0 Assignment

# %% [markdown]
# Name: Madhumitha Rajagopal
#
# UID: 121331472

# %%
#HW0 Assignment.ipynb

def character_frequency(s):
    ret = dict()
    ret['0'] = 0
    ret['1'] = 1
    return ret

character_frequency('google')

character_frequency('This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.')
# Out:
# {'0': 0, '1': 1}

# %% [markdown]
# GitHub Repository URL:
#
# https://github.com/rmadhu-umd/DATA602_FardinaAlam

# %% [markdown]
# GitHub Page URL:
#
# https://rmadhu-umd.github.io/madhu-bio/

# %% [markdown]
# #Screenshots

# %% [markdown]
# #Jupyter Notebook

# %% [markdown]
# ![Jupyter1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Jupyter2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Jupyter3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Google Colab

# %% [markdown]
# ![GoogleColab1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![GoogleColab2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Pytorch

# %% [markdown]
# ![Pytorch1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Pytorch2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Docker

# %% [markdown]
# ![Docker1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Docker2.jpg](data:image/jpeg;base64,...)
